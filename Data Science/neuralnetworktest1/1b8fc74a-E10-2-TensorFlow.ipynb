# %% [markdown]
# # E10-2 Introduction to TensorFlow

# %% [markdown]
# ## Procedure
# 1. Create a model
# 2. Build a computation graph
# 3. Run the graph in a session

# %% [markdown]
# ## Demo Example: Multiplication of Scalars

# %%
import os
os.getcwd()
# Out:
# 'c:\\code\\cphbusiness\\Data Science\\neuralnetworktest1'

# %%
import sys
sys.version
# Out:
# '3.9.1 (tags/v3.9.1:1e5d33e, Dec  7 2020, 17:08:21) [MSC v.1927 64 bit (AMD64)]'

# %%
# !python -V
# Out:
# Python 3.9.1

# %%
# !pip3 install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\cosby\appdata\roaming\python\python39\site-packages (2.5.0rc1)
# Requirement already satisfied: absl-py~=0.10 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: gast==0.4.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (2.5.0rc0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (3.15.8)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (0.36.2)WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
#
# Requirement already satisfied: tensorboard~=2.4 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (0.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\program files\python39\lib\site-packages (from tensorboard~=2.4->tensorflow) (49.2.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (1.30.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\cosby\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)

# %%
import tensorflow as tf
import numpy as np
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# ![image](imageabove.png)

# %% [markdown]
# ### Simple Computational Graph

# %% [markdown]
# Example: x1 * x2 + x3 = result<br>
#
# x1<br>
#     * multiply<br>
# x2<br>
#                 + add  =  result<br>
# x3    <br>

# %%
# Create a simple model and graph
# Each operator is a "node" in the computation graph
with tf.compat.v1.Session() as sess:
    x1 = tf.constant(4)
    x2 = tf.constant(5)
    x3 = tf.constant(3)
    product = tf.multiply(x1, x2)
    result = tf.add(x3, product)
    print(result)
    print(sess.run(result))
    sess.close()
# Out:
# Tensor("Add:0", shape=(), dtype=int32)
# 23

# %% [markdown]
# ## Demo Example: Multiplication of Vectors

# %%
# Intialize the Session
with tf.compat.v1.Session() as sess:
    # Initialize two vectors
    x1 = tf.constant([1,2,3,4])
    x2 = tf.constant([5,6,7,8])

    # Multiply them
    result = tf.multiply(x1, x2)

    # Print the result
    print(sess.run(result))

    # Close the session
    sess.close()
# Out:
# [ 5 12 21 32]

# %% [markdown]
# ## Demo Example: Multiplication of Matrices

# %%
# Intialize the Session
with tf.compat.v1.Session() as sess:
    matrix1 = tf.constant([[1., 2.], [3., 4.]])
    matrix2 = tf.constant([[5., 6.], [7., 8.]])
    product = tf.matmul(matrix1, matrix2)
    print(product)
    output = sess.run(product)
    print(output)
# Out:
# Tensor("MatMul:0", shape=(2, 2), dtype=float32)
# [[19. 22.]
#  [43. 50.]]

# %% [markdown]
# <hr>
# <hr>
